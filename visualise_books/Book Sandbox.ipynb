# %%
import os
import nltk
from nltk.corpus import stopwords
from nltk.corpus import PlaintextCorpusReader

corpus_root = os.path.join(os.path.abspath(os.curdir), 'data')
corpus = PlaintextCorpusReader(corpus_root, '.*')
stopwords = set(stopwords.words('english'))
print corpus.fileids()
# Out:
# ['Beyond Good and Evil_Nietzsche.txt', 'Laughter_Bergson.txt', 'Principles of Morals_Hume.txt', 'The Principles Of Aesthetics_Parker.txt', 'The Problems of Philosophy_Russell.txt', 'Towards a Theory of Knowledge_Philip.txt']

# %%
book1 = 'Laughter_Bergson.txt'

book1_fd = nltk.FreqDist([w.lower() for w in corpus.words(book1) if w.isalpha() and w.lower() not in stopwords])

book1_fd.most_common(1920/8)

# %%
book1_important_words = ['comic', 'life', 'laughter', 'certain', 'comedy', 'character', 'laugh', 'kind', 'idea', 'nature']

# %%
book2 = 'Principles of Morals_Hume.txt'

book2_fd = nltk.FreqDist([w.lower() for w in corpus.words(book2) if w.isalpha() and w.lower() not in stopwords])

book2_fd.most_common(1920/8)

# %%
book2_important_words = ['reason', 'society', 'nature', 'sentiment', 'without', 'justice', 'human', 'general', 'good', 'moral', 'virtue']

# %%
book3 = 'The Problems of Philosophy_Russell.txt'

book3_fd = nltk.FreqDist([w.lower() for w in corpus.words(book3) if w.isalpha() and w.lower() not in stopwords])

book3_fd.most_common(1920/8)
# Out:
# [(u'knowledge', 306),
#  (u'sense', 234),
#  (u'may', 173),
#  (u'must', 169),
#  (u'things', 167),
#  (u'know', 162),
#  (u'one', 156),
#  (u'us', 152),
#  (u'two', 149),
#  (u'thus', 146),
#  (u'data', 138),
#  (u'true', 130),
#  (u'fact', 108),
#  (u'object', 105),
#  (u'physical', 101),
#  (u'belief', 99),
#  (u'see', 98),
#  (u'objects', 95),
#  (u'relation', 94),
#  (u'gutenberg', 93),
#  (u'table', 93),
#  (u'certain', 91),
#  (u'cannot', 89),
#  (u'known', 89),
#  (u'truth', 89),
#  (u'project', 87),
#  (u'mind', 87),
#  (u'would', 86),
#  (u'philosophy', 85),
#  (u'self', 84),
#  (u'experience', 80),
#  (u'world', 78),
#  (u'acquaintance', 78),
#  (u'something', 78),
#  (u'different', 77),
#  (u'thing', 76),
#  (u'space', 74),
#  (u'particular', 74),
#  (u'general', 72),
#  (u'therefore', 71),
#  (u'acquainted', 71),
#  (u'time', 67),
#  (u'case', 67),
#  (u'shall', 67),
#  (u'upon', 66),
#  (u'man', 63),
#  (u'many', 62),
#  (u'say', 61),
#  (u'proposition', 61),
# ...

# %%
book3_important_words = ['knowledge', 'sense', 'things', 'know', 'data', 'true', 'fact', 'object', 'physical', 'belief']
